# %%
import plot_likert
import pandas as pd

df= pd.read_csv(r'/Users/muinde/Downloads/data_berlinnairobi2022_2022-08-29_10-37 - berlinnairobi2022 - data_berlinnairobi2022_2022-08-29_10-37 - berlinnairobi2022.csv')
df.head()
df = df.replace([1],'Strongly Disagree')
df = df.replace([2],'Disagree')
df = df.replace([3],'Neutral')
df = df.replace([4],'Agree')
df = df.replace([5],'Strongly Agree')
df = df.replace([6],'no comment')



df1= df.drop(columns=["Interview-Nummer (fortlaufend)", "city", "profession","expericence students", "experience doctors","Trolley Drama"])
df1.head()
myscale= \
    ['Strongly Disagree',
     'Disagree',
     'Neutral',
     'Agree',
     'Strongly Agree',
     'no comment']



plot_likert.plot_likert(df1,myscale, plot_percentage=True, colors=plot_likert.colors.likert7)
# Out:
# /Users/muinde/opt/anaconda3/lib/python3.9/site-packages/plot_likert/plot_likert.py:299: UserWarning: In your data, not all questions have the same number of responses. i.e., different numbers of people answered each question. Therefore, the percentages aren't directly comparable: X% for one question represents a different number of responses than X% for another question, yet they will appear the same in the percentage graph. This may be misleading to your reader.
#   warn(
# <AxesSubplot:xlabel='Percentage of Responses'>
